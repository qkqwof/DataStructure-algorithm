# %% [markdown]
# ## 깊이우선탐색(DFS)
#
# - Depth First Search의 약자로 넓이 우선 탐색을 의미<br>
#   하나의 경우의 수에 대하여 모든 경우의 수를 조사하고 다음 경우의 수를 조사하면서 해를 찾는 과정

# %% [markdown]
# ![DFS](https://user-images.githubusercontent.com/76687078/114281401-2658b480-9a79-11eb-81f9-2a234c73b4a5.png)

# %% [markdown]
# ## 깊이 우선탐색과 스택

# %% [markdown]
# ![DFS와스택](https://user-images.githubusercontent.com/76687078/114281413-32dd0d00-9a79-11eb-824c-783883241894.png)

# %% [markdown]
# ![DFS와스택2](https://user-images.githubusercontent.com/76687078/114281419-3a041b00-9a79-11eb-9e50-9968207702f1.png)
#
# 이런식으로 위에 있는 부분부터 계속 빼내면서 진행한다.

# %% [markdown]
# ## DFS 구현하기
#
# ![구현](https://user-images.githubusercontent.com/76687078/114281572-04136680-9a7a-11eb-9c7b-0d06a3c96e19.png)

# %% [markdown]
# 이런 식으로 진행을 하게 된다.
#
# ![구현1](https://user-images.githubusercontent.com/76687078/114281629-5785b480-9a7a-11eb-9f88-96d3ff99ab55.png)

# %% [markdown]
# 모든 진행과정이 끝나면 알고리즘이 종료된다.
#
# ![구현2](https://user-images.githubusercontent.com/76687078/114281665-9ddb1380-9a7a-11eb-9a1e-26a7ca338be7.png)

# %% [markdown]
# ## 깊이 우선탐색(DFS) 예시코드

# %% [markdown]
# ![%EA%B9%8A%EC%9D%B4%EC%9A%B0%EC%84%A0%ED%83%90%EC%83%89.png](attachment:%EA%B9%8A%EC%9D%B4%EC%9A%B0%EC%84%A0%ED%83%90%EC%83%89.png)

# %% [markdown]
# ## 너비우선탐색(BFS)
#
# - Breadth First Search의 약자로 넓이 우선 탐색을 의미<br>
#   하나의 경우의 수에 대한 다음 단계의 모든 경우의 수를 조사하면서 해를 찾는 과정

# %% [markdown]
# ![너비우선탐색 구조](https://user-images.githubusercontent.com/76687078/114281824-89e3e180-9a7b-11eb-9920-d5b94ce18614.png)

# %% [markdown]
# ## 너비우선탐색과 큐

# %% [markdown]
# ![너비우선탐색과큐](https://user-images.githubusercontent.com/76687078/114281868-d8917b80-9a7b-11eb-86ff-2a9bb5d710de.png)

# %% [markdown]
# ![너비우선탐색과큐2](https://user-images.githubusercontent.com/76687078/114281914-1393af00-9a7c-11eb-9350-a2f1f7dfc9a4.png)

# %% [markdown]
# ## 너비우선탐색 구현
#
# ![너비우선탐색 구현](https://user-images.githubusercontent.com/76687078/114281977-548bc380-9a7c-11eb-8a86-808e02460ef6.png)

# %% [markdown]
# 중간과정...
#
# ![너비구현2](https://user-images.githubusercontent.com/76687078/114282023-a46a8a80-9a7c-11eb-97c1-f7d1cbb189dd.png)

# %% [markdown]
# 마무리 과정
#
# ![너비구현3](https://user-images.githubusercontent.com/76687078/114282120-00cdaa00-9a7d-11eb-99ee-80faa4bb5d9c.png)

# %% [markdown]
# ## 너비우선탐색 예시코드

# %% [markdown]
# ![%EB%84%88%EB%B9%84%EC%9A%B0%EC%84%A0%ED%83%90%EC%83%89.png](attachment:%EB%84%88%EB%B9%84%EC%9A%B0%EC%84%A0%ED%83%90%EC%83%89.png)
